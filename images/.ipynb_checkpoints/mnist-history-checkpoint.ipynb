# %%
# %pylab inline
# %config InlineBackend.figure_formats = ['retina']
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mnist_df = pd.read_csv("mnist-history.csv")

# %%
mnist_df.dropna(inplace=True)
mnist_df
# Out:
#                                                  Name           Model  \
# 0                      linear classifier (1-layer NN)          linear
# 1                      linear classifier (1-layer NN)          linear
# 2                          pairwise linear classifier          linear
# 3                 K-nearest-neighbors, Euclidean (L2)             knn
# 4                 K-nearest-neighbors, Euclidean (L2)             knn
# 5                             K-nearest-neighbors, L3             knn
# 6                 K-nearest-neighbors, Euclidean (L2)             knn
# 7                 K-nearest-neighbors, Euclidean (L2)             knn
# 8                             K-nearest-neighbors, L3             knn
# 9                             K-nearest-neighbors, L3             knn
# 10                            K-nearest-neighbors, L3             knn
# 11             K-NN with non-linear deformation (IDM)             knn
# 12         K-NN with non-linear deformation (P2DHMDM)             knn
# 13                             K-NN, Tangent Distance             knn
# 14                       K-NN, shape context matching             knn
# 15                                     boosted stumps  boosted stumps
# 16               products of boosted stumps (3 terms)  boosted stumps
# 17                          boosted trees (17 leaves)  boosted stumps
# 18                            stumps on Haar features  boosted stumps
# 19                       product of stumps on Haar f.  boosted stumps
# 20                      40 PCA + quadratic classifier       nonlinear
# 21                       1000 RBF + linear classifier       nonlinear
# 22      Virtual SVM, deg-5 poly, 1-pixel translations             svm
# 24                               SVM deg 4 polynomial             svm
# 25                   Reduced Set SVM deg 5 polynomial             svm
# 26               Virtual SVM deg-9 poly [distortions]             svm
# 27          Virtual SVM, deg-9 poly, 1-pixel jittered             svm
# 28          Virtual SVM, deg-9 poly, 1-pixel jittered             svm
# 29          Virtual SVM, deg-9 poly, 2-pixel jittered             svm
# 30    2-layer NN, 300 hidden units, mean square error      neural net
# ..                                                ...             ...
# 40             2-layer NN, 800 HU, Cross-Entropy Loss      neural net
# 41  2-layer NN, 800 HU, cross-entropy [affine dist...      neural net
# 42      2-layer NN, 800 HU, MSE [elastic distortions]      neural net
# 43  2-layer NN, 800 HU, cross-entropy [elastic dis...      neural net
# 44  NN, 784-500-500-2000-30 + nearest neighbor, RB...      neural net
# 45  6-layer NN 784-2500-2000-1500-1000-500-10 (on ...      neural net
# 46  committee of 25 NN 784-800-10 [elastic distort...      neural net
# 47  deep convex net, unsup pre-training [no distor...      neural net
# 48                          Convolutional net LeNet-1         convnet
# 49                          Convolutional net LeNet-4         convnet
# 50  Convolutional net LeNet-4 with K-NN instead of...         convnet
# 51  Convolutional net LeNet-4 with local learning ...         convnet
# 52        Convolutional net LeNet-5, [no distortions]         convnet
# 53      Convolutional net LeNet-5, [huge distortions]         convnet
# 54           Convolutional net LeNet-5, [distortions]         convnet
# 55   Convolutional net Boosted LeNet-4, [distortions]         convnet
# 56  Trainable feature extractor + SVMs [no distort...         convnet
# 57  Trainable feature extractor + SVMs [elastic di...         convnet
# 58  Trainable feature extractor + SVMs [affine dis...         convnet
# 59  unsupervised sparse features + SVM, [no distor...         convnet
# 60  Convolutional net, cross-entropy [affine disto...         convnet
# 61  Convolutional net, cross-entropy [elastic dist...         convnet
# 62  large conv. net, random features [no distortions]         convnet
# 63   large conv. net, unsup features [no distortions]         convnet
# 64  large conv. net, unsup pretraining [no distort...         convnet
# 65  large conv. net, unsup pretraining [elastic di...         convnet
# 66  large conv. net, unsup pretraining [no distort...         convnet
# 67  large/deep conv. net, 1-20-40-60-80-100-120-12...         convnet
# 68  committee of 7 conv. net, 1-20-P-40-P-150-10 [...         convnet
# 69  committee of 35 conv. net, 1-20-P-40-P-150-10 ...         convnet
#
#                                         Preprocessing  Error    Year  \
# 0                                                none  12.00  1998.0
# 1                                           deskewing   8.40  1994.0
# 2                                           deskewing   7.60  1998.0
# 3                                                none   5.00  1998.0
# 4                                                none   3.09  2002.0
# 5                                                none   2.83  2002.0
# 6                                           deskewing   2.40  1994.0
# 7                  deskewing, noise removal, blurring   1.80  2002.0
# 8                  deskewing, noise removal, blurring   1.73  2002.0
# 9   deskewing, noise removal, blurring, 1 pixel shift   1.33  2002.0
# 10  deskewing, noise removal, blurring, 2 pixel shift   1.22  2002.0
# 11                                    shiftable edges   0.54  2007.0
# 12                                    shiftable edges   0.52  2007.0
# 13                        subsampling to 16x16 pixels   1.10  1994.0
# 14                   shape context feature extraction   0.63  2002.0
# 15                                               none   7.70  2009.0
# 16                                               none   1.26  2009.0
# 17                                               none   1.53  2009.0
# 18                                      Haar features   1.02  2009.0
# 19                                      Haar features   0.87  2009.0
# 20                                               none   3.30  1998.0
# 21                                               none   3.60  1998.0
# 22                                               todo   1.00  1996.0
# 24                                          deskewing   1.10  1994.0
# 25                                          deskewing   1.00  1998.0
# 26                                               none   0.80  1998.0
# 27                                               none   0.68  2002.0
# 28                                          deskewing   0.68  2002.0
# 29                                          deskewing   0.56  2002.0
# 30                                               none   4.70  1998.0
# ..                                                ...    ...     ...
# 40                                               none   1.60  2003.0
# 41                                               none   1.10  2003.0
# 42                                               none   0.90  2003.0
# 43                                               none   0.70  2003.0
# 44                                               none   1.00  2007.0
# 45                                               none   0.35  2010.0
# 46                    width normalization, deslanting   0.39  2011.0
# 47                                               none   0.83  2010.0
# 48                        subsampling to 16x16 pixels   1.70  1994.0
# 49                                               none   1.10  1994.0
# 50                                               none   1.10  1994.0
# 51                                               none   1.10  1994.0
# 52                                               none   0.95  1994.0
# 53                                               none   0.85  1994.0
# 54                                               none   0.80  1994.0
# 55                                               none   0.70  1994.0
# 56                                               none   0.83  2007.0
# 57                                               none   0.56  2007.0
# 58                                               none   0.54  2007.0
# 59                                               none   0.59  2008.0
# 60                                               none   0.60  2003.0
# 61                                               none   0.40  2003.0
# 62                                               none   0.89  2007.0
# 63                                               none   0.62  2007.0
# 64                                               none   0.60  2006.0
# 65                                               none   0.39  2006.0
# 66                                               none   0.53  2009.0
# 67                                               none   0.35  2011.0
# 68                                width normalization   0.27  2011.0
# 69                                width normalization   0.23  2012.0
#
#                                                  Cite
# 0                                   LeCun et al. 1998
# 1                                   Bottou et al 1994
# 2                                   LeCun et al. 1998
# 3                                   LeCun et al. 1998
# 4                          Kenneth Wilder, U. Chicago
# 5                          Kenneth Wilder, U. Chicago
# 6                                   Bottou et al 1994
# 7                          Kenneth Wilder, U. Chicago
# 8                          Kenneth Wilder, U. Chicago
# 9                          Kenneth Wilder, U. Chicago
# 10                         Kenneth Wilder, U. Chicago
# 11                      Keysers et al. IEEE PAMI 2007
# 12                      Keysers et al. IEEE PAMI 2007
# 13                                  Bottou et al 1994
# 14                     Belongie et al. IEEE PAMI 2002
# 15                             Kegl et al., ICML 2009
# 16                             Kegl et al., ICML 2009
# 17                             Kegl et al., ICML 2009
# 18                             Kegl et al., ICML 2009
# 19                             Kegl et al., ICML 2009
# 20                                  LeCun et al. 1998
# 21                                  LeCun et al. 1998
# 22                               Schlokopf et al 1996
# 24                                  Bottou et al 1994
# 25                                  LeCun et al. 1998
# 26                                  LeCun et al. 1998
# 27                    DeCoste and Scholkopf, MLJ 2002
# 28                    DeCoste and Scholkopf, MLJ 2002
# 29                    DeCoste and Scholkopf, MLJ 2002
# 30                                  LeCun et al. 1998
# ..                                                ...
# 40                          Simard et al., ICDAR 2003
# 41                          Simard et al., ICDAR 2003
# 42                          Simard et al., ICDAR 2003
# 43                          Simard et al., ICDAR 2003
# 44            Salakhutdinov and Hinton, AI-Stats 2007
# 45  Ciresan et al. Neural Computation 10, 2010 and...
# 46                            Meier et al. ICDAR 2011
# 47                       Deng et al. Interspeech 2010
# 48                                  Bottou et al 1994
# 49                                  Bottou et al 1994
# 50                                  Bottou et al 1994
# 51                                  Bottou et al 1994
# 52                                  Bottou et al 1994
# 53                                  Bottou et al 1994
# 54                                  Bottou et al 1994
# 55                                  Bottou et al 1994
# 56       Lauer et al., Pattern Recognition 40-6, 2007
# 57       Lauer et al., Pattern Recognition 40-6, 2007
# 58       Lauer et al., Pattern Recognition 40-6, 2007
# 59                      Labusch et al., IEEE TNN 2008
# 60                          Simard et al., ICDAR 2003
# 61                          Simard et al., ICDAR 2003
# 62                          Ranzato et al., CVPR 2007
# 63                          Ranzato et al., CVPR 2007
# 64                          Ranzato et al., NIPS 2006
# 65                          Ranzato et al., NIPS 2006
# 66                          Jarrett et al., ICCV 2009
# 67                          Ciresan et al. IJCAI 2011
# 68                          Ciresan et al. ICDAR 2011
# 69                           Ciresan et al. CVPR 2012
#
# [69 rows x 6 columns]

# %%
model_list = mnist_df.Model.unique()
year_list = np.arange(mnist_df.Year.min(), mnist_df.Year.max() + 1, dtype=int)

record_lod = []

for model in model_list:
    for year in year_list:
        my_query = mnist_df.query(f"(Model=='{model}') & (Year <= {year})")
        if len(my_query) < 1:
            record_lod.append({
                "model": model,
                "year": year,
                "error": np.nan,
                "cite": np.nan,
            })
        else:
            min_i = my_query.Error.idxmin()
            record_lod.append({
                "model": model,
                "year": year,
                "error": my_query.loc[min_i, "Error"],
                "cite": my_query.loc[min_i, "Cite"],
            })

# %%
record_df = pd.DataFrame(record_lod)
record_df.plot.line()

# %%
# subrecord_df = record_df[record_df.model.isin(
#     ["knn", "convnet", "neural net", "svm"])]

# %%
figsize(8,8)
sns.lineplot(x="year", y="error", hue="model", data=record_df)
plt.semilogy()
newticks = [.1, .25, .5, 1, 2.5, 5, 10]
plt.yticks(newticks, [f"{t:g}" for t in newticks]);
plt.xticks(year_list[::2], [str(y) for y in year_list[::2]])
title("MNIST record by model type by year.")
ylabel("Error rate")
xlabel("Year")
# Out:
# Text(0.5,0,'Year')
